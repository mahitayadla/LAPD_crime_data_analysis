# %% [markdown]
# ### Load the dataset
#
# This dataset contains records of reported crimes in the City of Los Angeles, covering the period from 2020 through September 2025 (the date the data was downloaded).

# %%
import pandas as pd

df=pd.read_csv(r"C:\Users\mahit\Downloads\Crime_Data_from_2020_to_Present.csv")
df.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0  211507896  04/11/2021 12:00:00 AM  11/07/2020 12:00:00 AM       845    15
# 1  201516622  10/21/2020 12:00:00 AM  10/18/2020 12:00:00 AM      1845    15
# 2  240913563  12/10/2024 12:00:00 AM  10/30/2020 12:00:00 AM      1240     9
# 3  210704711  12/24/2020 12:00:00 AM  12/24/2020 12:00:00 AM      1310     7
# 4  201418201  10/03/2020 12:00:00 AM  09/29/2020 12:00:00 AM      1830    14
#
#      AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0  N Hollywood         1502         2     354
# 1  N Hollywood         1521         1     230
# 2     Van Nuys          933         2     354
# 3     Wilshire          782         1     331
# 4      Pacific         1454         1     420
#
#                                          Crm Cd Desc  ... Status  Status Desc  \
# 0                                  THEFT OF IDENTITY  ...     IC  Invest Cont
# 1     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  ...     IC  Invest Cont
# 2                                  THEFT OF IDENTITY  ...     IC  Invest Cont
# 3  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...  ...     IC  Invest Cont
# 4    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)  ...     IC  Invest Cont
#
#   Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 0    354.0      NaN       NaN      NaN
# 1    230.0      NaN       NaN      NaN
# 2    354.0      NaN       NaN      NaN
# 3    331.0      NaN       NaN      NaN
# 4    420.0      NaN       NaN      NaN
#
#                                    LOCATION Cross Street      LAT       LON
# 0   7800    BEEMAN                       AV          NaN  34.2124 -118.4092
# 1           ATOLL                        AV     N  GAULT  34.1993 -118.4203
# 2  14600    SYLVAN                       ST          NaN  34.1847 -118.4509
# 3   6000    COMEY                        AV          NaN  34.0339 -118.3747
# 4                   4700    LA VILLA MARINA          NaN  33.9813 -118.4350
#
# [5 rows x 28 columns]

# %%
#number of rows and columns
num_rows = df.shape[0]
num_cols = df.shape[1]
print("Number of Rows:",num_rows)
print("Number of Columns:",num_cols)
# Out:
# Number of Rows: 1004991
# Number of Columns: 28

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1004991 entries, 0 to 1004990
# Data columns (total 28 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   DR_NO           1004991 non-null  int64
#  1   Date Rptd       1004991 non-null  object
#  2   DATE OCC        1004991 non-null  object
#  3   TIME OCC        1004991 non-null  int64
#  4   AREA            1004991 non-null  int64
#  5   AREA NAME       1004991 non-null  object
#  6   Rpt Dist No     1004991 non-null  int64
#  7   Part 1-2        1004991 non-null  int64
#  8   Crm Cd          1004991 non-null  int64
#  9   Crm Cd Desc     1004991 non-null  object
#  10  Mocodes         853372 non-null   object
#  11  Vict Age        1004991 non-null  int64
#  12  Vict Sex        860347 non-null   object
#  13  Vict Descent    860335 non-null   object
#  14  Premis Cd       1004975 non-null  float64
#  15  Premis Desc     1004403 non-null  object
#  16  Weapon Used Cd  327247 non-null   float64
#  17  Weapon Desc     327247 non-null   object
#  18  Status          1004990 non-null  object
#  19  Status Desc     1004991 non-null  object
#  20  Crm Cd 1        1004980 non-null  float64
#  21  Crm Cd 2        69160 non-null    float64
#  22  Crm Cd 3        2314 non-null     float64
#  23  Crm Cd 4        64 non-null       float64
#  24  LOCATION        1004991 non-null  object
#  25  Cross Street    154236 non-null   object
#  26  LAT             1004991 non-null  float64
#  27  LON             1004991 non-null  float64
# dtypes: float64(8), int64(7), object(13)
# memory usage: 214.7+ MB

# %%
duplicates = df[df.duplicated()]

print(duplicates)
# Out:
# Empty DataFrame
# Columns: [DR_NO, Date Rptd, DATE OCC, TIME OCC, AREA, AREA NAME, Rpt Dist No, Part 1-2, Crm Cd, Crm Cd Desc, Mocodes, Vict Age, Vict Sex, Vict Descent, Premis Cd, Premis Desc, Weapon Used Cd, Weapon Desc, Status, Status Desc, Crm Cd 1, Crm Cd 2, Crm Cd 3, Crm Cd 4, LOCATION, Cross Street, LAT, LON]
# Index: []
#
# [0 rows x 28 columns]

# %% [markdown]
# ### Victim Sex Column
#
# The `vict_sex`  column represents the gender of the victim.
# Upon inspection, this column contains **missing (null) values** for some records.

# %%
df['Vict Sex'].value_counts(dropna=False)
# Out:
# Vict Sex
# M      403879
# F      358580
# NaN    144644
# X       97773
# H         114
# -           1
# Name: count, dtype: int64

# %% [markdown]
# According to the official dataset documentation, the vict_sex field should contain only three values: M, F, and X. However, the dataset also includes NaN, H, and -, which are inconsistent and need to be cleaned.

# %%
import numpy as np

df['Vict Sex']=np.where(df['Vict Sex'].isin(['X','H','-']) | (df['Vict Sex'].isna()),'X',df['Vict Sex'])

# %%
df['Vict Sex'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1004991 entries, 0 to 1004990
# Series name: Vict Sex
# Non-Null Count    Dtype
# --------------    -----
# 1004991 non-null  object
# dtypes: object(1)
# memory usage: 7.7+ MB

# %%
df['Vict Sex'].value_counts(dropna=False)
# Out:
# Vict Sex
# M    403879
# F    358580
# X    242532
# Name: count, dtype: int64

# %% [markdown]
# ### Victim Descent Column
#
# The `vict_descent`  column represents the descent details of the victim.
# Upon inspection, this column contains **missing (null) values** for some records.

# %%
df['Vict Descent'].value_counts(dropna=False)
# Out:
# Vict Descent
# H      296404
# W      201442
# NaN    144656
# B      135816
# X      106685
# O       78005
# A       21340
# K        5990
# F        4838
# C        4631
# J        1586
# V        1195
# I        1015
# Z         577
# P         288
# U         221
# D          91
# L          77
# G          74
# S          58
# -           2
# Name: count, dtype: int64

# %% [markdown]
# According to the official dataset documentation, the `Vict Descent` field should contain only the following values:
#
# - A - Other Asian
# - B - Black
# - C - Chinese
# - D - Cambodian
# - F - Filipino
# - G - Guamanian
# - H - Hispanic/Latin/Mexican
# - I - American Indian/Alaskan Native
# - J - Japanese
# - K - Korean
# - L - Laotian
# - O - Other
# - P - Pacific Islander
# - S - Samoan
# - U - Hawaiian
# - V - Vietnamese
# - W - White
# - X - Unknown
# - Z - Asian Indian
#
# However, the field also contains **NaN** and `-`, which are inconsistent and need to be cleaned.

# %%
import numpy as np

df['Vict Descent']=np.where((df['Vict Descent']=='-') | (df['Vict Descent'].isna()),'X',df['Vict Descent'])

# %%
df['Vict Descent'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1004991 entries, 0 to 1004990
# Series name: Vict Descent
# Non-Null Count    Dtype
# --------------    -----
# 1004991 non-null  object
# dtypes: object(1)
# memory usage: 7.7+ MB

# %%
df['Vict Descent'].value_counts(dropna=False)
# Out:
# Vict Descent
# H    296404
# X    251343
# W    201442
# B    135816
# O     78005
# A     21340
# K      5990
# F      4838
# C      4631
# J      1586
# V      1195
# I      1015
# Z       577
# P       288
# U       221
# D        91
# L        77
# G        74
# S        58
# Name: count, dtype: int64

# %% [markdown]
# ### Victim Age Column
#
# The `Vict Age`  column represents the age details of the victim.
#
# Note: The `Vict Age` column has ~27% missing values. These rows have been retained as nulls and are ignored in visualizations and calculations where appropriate.

# %%
df['Vict Age'].describe()
# Out:
# count    1.004991e+06
# mean     2.891706e+01
# std      2.199272e+01
# min     -4.000000e+00
# 25%      0.000000e+00
# 50%      3.000000e+01
# 75%      4.400000e+01
# max      1.200000e+02
# Name: Vict Age, dtype: float64

# %% [markdown]
# According to the documentation, the values are two diigits 01-99
# The maximum value present in the age column is 20, while that may be correct, the documentation proves that it is an outlier.

# %%
df['Vict Age']=np.where(df['Vict Age'] <=0,np.nan,df['Vict Age'])

# %%
df['Vict Age']=np.where(df['Vict Age'] >99,np.nan,df['Vict Age'])

# %%
df['Vict Age'] = df['Vict Age'].astype('Int64')

# %%
df['Vict Age'].dtype
# Out:
# Int64Dtype()

# %%
df['Vict Age'].describe()
# Out:
# count     735631.0
# mean     39.505475
# std      15.571176
# min            2.0
# 25%           28.0
# 50%           37.0
# 75%           50.0
# max           99.0
# Name: Vict Age, dtype: Float64

# %%
df['Vict Age'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1004991 entries, 0 to 1004990
# Series name: Vict Age
# Non-Null Count   Dtype
# --------------   -----
# 735631 non-null  Int64
# dtypes: Int64(1)
# memory usage: 8.6 MB

# %% [markdown]
# ### Area Column
# The `Area Name` column represents the geographical area/patrol division

# %%
df['AREA NAME'] = df['AREA NAME'].str.strip()
df['AREA NAME'].value_counts(dropna=False)
# Out:
# AREA NAME
# Central        69670
# 77th Street    61758
# Pacific        59514
# Southwest      57441
# Hollywood      52429
# N Hollywood    51107
# Olympic        50071
# Southeast      49936
# Newton         49177
# Wilshire       48239
# Rampart        46825
# West LA        45729
# Northeast      42963
# Van Nuys       42883
# West Valley    42156
# Devonshire     41756
# Harbor         41394
# Topanga        41374
# Mission        40351
# Hollenbeck     37085
# Foothill       33133
# Name: count, dtype: int64

# %% [markdown]
# ### Crime Code description
# The `Crm Cd Desc` column represents the crime committed

# %%
df['Crm Cd Desc'].value_counts(dropna=False)
# Out:
# Crm Cd Desc
# VEHICLE - STOLEN                                           115190
# BATTERY - SIMPLE ASSAULT                                    74839
# BURGLARY FROM VEHICLE                                       63517
# THEFT OF IDENTITY                                           62537
# VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)     61092
#                                                             ...
# FIREARMS EMERGENCY PROTECTIVE ORDER (FIREARMS EPO)              5
# FIREARMS RESTRAINING ORDER (FIREARMS RO)                        4
# DISHONEST EMPLOYEE ATTEMPTED THEFT                              4
# TRAIN WRECKING                                                  1
# DRUNK ROLL - ATTEMPT                                            1
# Name: count, Length: 140, dtype: int64

# %%
df['Premis Desc'].value_counts(dropna=False)
# Out:
# Premis Desc
# STREET                                          261284
# SINGLE FAMILY DWELLING                          163654
# MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)    119011
# PARKING LOT                                      69147
# OTHER BUSINESS                                   47647
#                                                  ...
# MTA - SILVER LINE - DOWNTOWN STREET STOPS            2
# HORSE RACING/SANTA ANITA PARK*                       2
# MTA - SILVER LINE - LAC/USC MEDICAL CENTER           2
# DEPT OF DEFENSE FACILITY                             2
# TRAM/STREETCAR(BOXLIKE WAG ON RAILS)*                1
# Name: count, Length: 307, dtype: int64

# %%
df['Premis Desc'].isna().sum()
# Out:
# 588

# %%
df['Premis Cd'].isna().sum()
# Out:
# 16

# %%
mapping_df = df[df['Premis Desc'].notna()]
mapping_df['Premis Cd'] = mapping_df['Premis Cd'].astype(int)  
premis_mapping = dict(zip(mapping_df['Premis Cd'], mapping_df['Premis Desc']))
list(premis_mapping.items())[:5]
# Out:
# C:\Users\mahit\AppData\Local\Temp\ipykernel_2400\2447238421.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mapping_df['Premis Cd'] = mapping_df['Premis Cd'].astype(int)
# [(501, 'SINGLE FAMILY DWELLING'),
#  (102, 'SIDEWALK'),
#  (101, 'STREET'),
#  (103, 'ALLEY'),
#  (502, 'MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)')]

# %%
df['Premis Desc'] = df.apply(lambda row: premis_mapping.get(row['Premis Cd']) if pd.isna(row['Premis Desc']) else row['Premis Desc'],axis=1)

# %%
df['Premis Cd'] = df.apply(lambda row: premis_mapping.get(row['Premis Desc']) if pd.isna(row['Premis Cd']) else row['Premis Cd'],axis=1)

# %%
df['Premis Cd'].describe()
# Out:
# count    1.004975e+06
# mean     3.056201e+02
# std      2.193021e+02
# min      1.010000e+02
# 25%      1.010000e+02
# 50%      2.030000e+02
# 75%      5.010000e+02
# max      9.760000e+02
# Name: Premis Cd, dtype: float64

# %%
df['Premis Desc'].describe()
# Out:
# count     1004403
# unique        306
# top        STREET
# freq       261284
# Name: Premis Desc, dtype: object

# %%
df['Premis Cd'].fillna(0, inplace=True)
df['Premis Desc'].fillna('Not Mentioned', inplace=True)
# Out:
# C:\Users\mahit\AppData\Local\Temp\ipykernel_2400\1621091333.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Premis Cd'].fillna(0, inplace=True)
# C:\Users\mahit\AppData\Local\Temp\ipykernel_2400\1621091333.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Premis Desc'].fillna('Not Mentioned', inplace=True)

# %% [markdown]
# ### Temporal Information
# - The `Date Rptd` column represents the date the crime was reported.
# - The `DATE OCC` column represents the date thr crime occurred.
# - The `TIME OCC` column represents the time the crime was occured.

# %%
df["Date Rptd"]=pd.to_datetime(df["Date Rptd"])
df["DATE OCC"]=pd.to_datetime(df["DATE OCC"])
# Out:
# C:\Users\mahit\AppData\Local\Temp\ipykernel_2400\1777629952.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Date Rptd"]=pd.to_datetime(df["Date Rptd"])
# C:\Users\mahit\AppData\Local\Temp\ipykernel_2400\1777629952.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["DATE OCC"]=pd.to_datetime(df["DATE OCC"])

# %%
#converting military time format to HH format

df['TIME OCC'] = df['TIME OCC'].astype(str).str.zfill(4)
# Extract the hour as integer
df['HOUR_OCC'] = df['TIME OCC'].str.slice(0, 2)

# %%
df.head()
# Out:
#        DR_NO  Date Rptd   DATE OCC TIME OCC  AREA    AREA NAME  Rpt Dist No  \
# 0  211507896 2021-04-11 2020-11-07     0845    15  N Hollywood         1502
# 1  201516622 2020-10-21 2020-10-18     1845    15  N Hollywood         1521
# 2  240913563 2024-12-10 2020-10-30     1240     9     Van Nuys          933
# 3  210704711 2020-12-24 2020-12-24     1310     7     Wilshire          782
# 4  201418201 2020-10-03 2020-09-29     1830    14      Pacific         1454
#
#    Part 1-2  Crm Cd                                        Crm Cd Desc  ...  \
# 0         2     354                                  THEFT OF IDENTITY  ...
# 1         1     230     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  ...
# 2         2     354                                  THEFT OF IDENTITY  ...
# 3         1     331  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...  ...
# 4         1     420    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)  ...
#
#    Status Desc  Crm Cd 1 Crm Cd 2 Crm Cd 3  Crm Cd 4  \
# 0  Invest Cont     354.0      NaN      NaN       NaN
# 1  Invest Cont     230.0      NaN      NaN       NaN
# 2  Invest Cont     354.0      NaN      NaN       NaN
# 3  Invest Cont     331.0      NaN      NaN       NaN
# 4  Invest Cont     420.0      NaN      NaN       NaN
#
#                                    LOCATION  Cross Street      LAT       LON  \
# 0   7800    BEEMAN                       AV           NaN  34.2124 -118.4092
# 1           ATOLL                        AV      N  GAULT  34.1993 -118.4203
# 2  14600    SYLVAN                       ST           NaN  34.1847 -118.4509
# 3   6000    COMEY                        AV           NaN  34.0339 -118.3747
# 4                   4700    LA VILLA MARINA           NaN  33.9813 -118.4350
#
#   HOUR_OCC
# 0       08
# 1       18
# 2       12
# 3       13
# 4       18
#
# [5 rows x 29 columns]

# %%
df['TIME OCC'].isna().sum()
# Out:
# 0

# %%
invalid_hours = df.loc[~df['HOUR_OCC'].astype(str).str.match(r'^(?:[01]\d|2[0-3])$'), ['HOUR_OCC']]
invalid_hours
# Out:
# Empty DataFrame
# Columns: [HOUR_OCC]
# Index: []

# %% [markdown]
# ###  Case Status Information
# - The `Status` column represents the status code of the case.
# - The `Status Desc` column defines the status code provided.

# %%
df_counts = df.groupby(['Status', 'Status Desc']).size().reset_index(name='count')

# %%
print(df_counts)
# Out:
#   Status   Status Desc   count
# 0     AA  Adult Arrest   87155
# 1     AO   Adult Other  109802
# 2     CC           UNK       6
# 3     IC   Invest Cont  802862
# 4     JA    Juv Arrest    3286
# 5     JO     Juv Other    1879

# %%
print(sum(df_counts["count"]))
# Out:
# 1004990

# %% [markdown]
# ### Cleaning up the data

# %%
df.drop(columns=['Crm Cd 1', 'Crm Cd 2','Crm Cd 3','Crm Cd 4'], inplace=True)

# %%
df.drop(columns=['Part 1-2','Cross Street','Mocodes','Weapon Used Cd','Weapon Desc'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1004991 entries, 0 to 1004990
# Data columns (total 20 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   DR_NO         1004991 non-null  int64
#  1   Date Rptd     1004991 non-null  datetime64[ns]
#  2   DATE OCC      1004991 non-null  datetime64[ns]
#  3   TIME OCC      1004991 non-null  object
#  4   AREA          1004991 non-null  int64
#  5   AREA NAME     1004991 non-null  object
#  6   Rpt Dist No   1004991 non-null  int64
#  7   Crm Cd        1004991 non-null  int64
#  8   Crm Cd Desc   1004991 non-null  object
#  9   Vict Age      735631 non-null   Int64
#  10  Vict Sex      1004991 non-null  object
#  11  Vict Descent  1004991 non-null  object
#  12  Premis Cd     1004991 non-null  float64
#  13  Premis Desc   1004991 non-null  object
#  14  Status        1004990 non-null  object
#  15  Status Desc   1004991 non-null  object
#  16  LOCATION      1004991 non-null  object
#  17  LAT           1004991 non-null  float64
#  18  LON           1004991 non-null  float64
#  19  HOUR_OCC      1004991 non-null  object
# dtypes: Int64(1), datetime64[ns](2), float64(3), int64(4), object(10)
# memory usage: 154.3+ MB

# %% [markdown]
# ### Validation

# %%
df['LAT'].describe()
# Out:
# count    1.004991e+06
# mean     3.399821e+01
# std      1.610713e+00
# min      0.000000e+00
# 25%      3.401470e+01
# 50%      3.405890e+01
# 75%      3.416490e+01
# max      3.433430e+01
# Name: LAT, dtype: float64

# %%
df['LON'].describe()
# Out:
# count    1.004991e+06
# mean    -1.180909e+02
# std      5.582386e+00
# min     -1.186676e+02
# 25%     -1.184305e+02
# 50%     -1.183225e+02
# 75%     -1.182739e+02
# max      0.000000e+00
# Name: LON, dtype: float64

# %%
df['LAT'] = df['LAT'].replace(0, np.nan)
df['LON'] = df['LON'].replace(0, np.nan)

# %%
df['LON'].describe()
# Out:
# count    1.002751e+06
# mean    -1.183547e+02
# std      1.044454e-01
# min     -1.186676e+02
# 25%     -1.184309e+02
# 50%     -1.183230e+02
# 75%     -1.182740e+02
# max     -1.181554e+02
# Name: LON, dtype: float64

# %%
df.head(10)
# Out:
#        DR_NO  Date Rptd   DATE OCC TIME OCC  AREA    AREA NAME  Rpt Dist No  \
# 0  211507896 2021-04-11 2020-11-07     0845    15  N Hollywood         1502
# 1  201516622 2020-10-21 2020-10-18     1845    15  N Hollywood         1521
# 2  240913563 2024-12-10 2020-10-30     1240     9     Van Nuys          933
# 3  210704711 2020-12-24 2020-12-24     1310     7     Wilshire          782
# 4  201418201 2020-10-03 2020-09-29     1830    14      Pacific         1454
# 5  240412063 2024-12-11 2020-11-11     1210     4   Hollenbeck          429
# 6  240317069 2024-12-16 2020-04-16     1350     3    Southwest          396
# 7  201115217 2020-10-29 2020-07-07     1400    11    Northeast         1133
# 8  241708596 2024-04-20 2020-03-02     1200    17   Devonshire         1729
# 9  242113813 2024-12-18 2020-09-01     0900    21      Topanga         2196
#
#    Crm Cd                                        Crm Cd Desc  Vict Age  \
# 0     354                                  THEFT OF IDENTITY        31
# 1     230     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT        32
# 2     354                                  THEFT OF IDENTITY        30
# 3     331  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...        47
# 4     420    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)        63
# 5     354                                  THEFT OF IDENTITY        35
# 6     354                                  THEFT OF IDENTITY        21
# 7     812  CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 ...        14
# 8     354                                  THEFT OF IDENTITY        43
# 9     354                                  THEFT OF IDENTITY        57
#
#   Vict Sex Vict Descent  Premis Cd  \
# 0        M            H      501.0
# 1        M            H      102.0
# 2        M            W      501.0
# 3        F            A      101.0
# 4        M            H      103.0
# 5        M            B      502.0
# 6        F            B      501.0
# 7        F            H      121.0
# 8        M            W      501.0
# 9        M            W      501.0
#
#                                     Premis Desc Status  Status Desc  \
# 0                        SINGLE FAMILY DWELLING     IC  Invest Cont
# 1                                      SIDEWALK     IC  Invest Cont
# 2                        SINGLE FAMILY DWELLING     IC  Invest Cont
# 3                                        STREET     IC  Invest Cont
# 4                                         ALLEY     IC  Invest Cont
# 5  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)     IC  Invest Cont
# 6                        SINGLE FAMILY DWELLING     IC  Invest Cont
# 7                   YARD (RESIDENTIAL/BUSINESS)     AO  Adult Other
# 8                        SINGLE FAMILY DWELLING     IC  Invest Cont
# 9                        SINGLE FAMILY DWELLING     IC  Invest Cont
#
#                                    LOCATION      LAT       LON HOUR_OCC
# 0   7800    BEEMAN                       AV  34.2124 -118.4092       08
# 1           ATOLL                        AV  34.1993 -118.4203       18
# 2  14600    SYLVAN                       ST  34.1847 -118.4509       12
# 3   6000    COMEY                        AV  34.0339 -118.3747       13
# 4                   4700    LA VILLA MARINA  33.9813 -118.4350       18
# 5   5300    CRONUS                       ST  34.0830 -118.1678       12
# 6    900 W  40TH                         PL  34.0100 -118.2900       13
# 7   3000    ACRESITE                     ST  34.1107 -118.2589       14
# 8  17700    SIMONDS                      ST  34.2763 -118.5210       12
# 9  20900    MARMORA                      ST  34.1493 -118.5886       09

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1004991 entries, 0 to 1004990
# Data columns (total 20 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   DR_NO         1004991 non-null  int64
#  1   Date Rptd     1004991 non-null  datetime64[ns]
#  2   DATE OCC      1004991 non-null  datetime64[ns]
#  3   TIME OCC      1004991 non-null  object
#  4   AREA          1004991 non-null  int64
#  5   AREA NAME     1004991 non-null  object
#  6   Rpt Dist No   1004991 non-null  int64
#  7   Crm Cd        1004991 non-null  int64
#  8   Crm Cd Desc   1004991 non-null  object
#  9   Vict Age      735631 non-null   Int64
#  10  Vict Sex      1004991 non-null  object
#  11  Vict Descent  1004991 non-null  object
#  12  Premis Cd     1004991 non-null  float64
#  13  Premis Desc   1004991 non-null  object
#  14  Status        1004990 non-null  object
#  15  Status Desc   1004991 non-null  object
#  16  LOCATION      1004991 non-null  object
#  17  LAT           1002751 non-null  float64
#  18  LON           1002751 non-null  float64
#  19  HOUR_OCC      1004991 non-null  object
# dtypes: Int64(1), datetime64[ns](2), float64(3), int64(4), object(10)
# memory usage: 154.3+ MB

# %%
df['Status'].value_counts()
# Out:
# Status
# IC    802862
# AO    109802
# AA     87155
# JA      3286
# JO      1879
# CC         6
# Name: count, dtype: int64

# %%
df['Crm Cd Desc'].value_counts()
# Out:
# Crm Cd Desc
# VEHICLE - STOLEN                                           115190
# BATTERY - SIMPLE ASSAULT                                    74839
# BURGLARY FROM VEHICLE                                       63517
# THEFT OF IDENTITY                                           62537
# VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)     61092
#                                                             ...
# FIREARMS EMERGENCY PROTECTIVE ORDER (FIREARMS EPO)              5
# FIREARMS RESTRAINING ORDER (FIREARMS RO)                        4
# DISHONEST EMPLOYEE ATTEMPTED THEFT                              4
# TRAIN WRECKING                                                  1
# DRUNK ROLL - ATTEMPT                                            1
# Name: count, Length: 140, dtype: int64

# %%
pd.set_option('display.max_rows', None)
unique_pairs = df[['Crm Cd', 'Crm Cd Desc']].drop_duplicates()
unique_pairs
# Out:
#         Crm Cd                                        Crm Cd Desc
# 0          354                                  THEFT OF IDENTITY
# 1          230     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# 3          331  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...
# 4          420    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)
# 7          812  CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 ...
# 12         510                                   VEHICLE - STOLEN
# 13         310                                           BURGLARY
# 14         330                              BURGLARY FROM VEHICLE
# 15         440                 THEFT PLAIN - PETTY ($950 & UNDER)
# 16         626                  INTIMATE PARTNER - SIMPLE ASSAULT
# 17         624                           BATTERY - SIMPLE ASSAULT
# 25         745           VANDALISM - MISDEAMEANOR ($399 OR UNDER)
# 26         520                           VEHICLE - ATTEMPT STOLEN
# 27         740  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
# 28         210                                            ROBBERY
# 44         906           FIREARMS RESTRAINING ORDER (FIREARMS RO)
# 46         480                                      BIKE - STOLEN
# 48         668         EMBEZZLEMENT, GRAND THEFT ($950.01 & OVER)
# 50         627            CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT
# 62         930             CRIMINAL THREATS - NO WEAPON DISPLAYED
# 68         341  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...
# 70         860                        BATTERY WITH SEXUAL CONTACT
# 71         956            LETTERS, LEWD  -  TELEPHONE CALLS, LEWD
# 77         900                           VIOLATION OF COURT ORDER
# 91         648                                              ARSON
# 93         901                     VIOLATION OF RESTRAINING ORDER
# 105        350                                      THEFT, PERSON
# 112        903                                  CONTEMPT OF COURT
# 119        236              INTIMATE PARTNER - AGGRAVATED ASSAULT
# 129        220                                  ATTEMPTED ROBBERY
# 133        760                    LEWD/LASCIVIOUS ACTS WITH CHILD
# 136        946                          OTHER MISCELLANEOUS CRIME
# 142        761                                    BRANDISH WEAPON
# 150        888                                        TRESPASSING
# 151        666                                     BUNCO, ATTEMPT
# 178        442           SHOPLIFTING - PETTY THEFT ($950 & UNDER)
# 183        320                                BURGLARY, ATTEMPTED
# 188        649                   DOCUMENT FORGERY / STOLEN FELONY
# 199        343           SHOPLIFTING-GRAND THEFT ($950.01 & OVER)
# 215        890                                   FAILURE TO YIELD
# 224        623                            BATTERY POLICE (SIMPLE)
# 258        522  VEHICLE, STOLEN - OTHER (MOTORIZED SCOOTERS, B...
# 264        237                     CHILD NEGLECT (SEE 300 W.I.C.)
# 287        122                                    RAPE, ATTEMPTED
# 288        662                                 BUNCO, GRAND THEFT
# 311        954                                       CONTRIBUTING
# 349        805                                            PIMPING
# 376        625                                      OTHER ASSAULT
# 455        821  SODOMY/SEXUAL CONTACT B/W PENIS OF ONE PERS TO...
# 479        121                                     RAPE, FORCIBLE
# 480        845          SEX OFFENDER REGISTRANT OUT OF COMPLIANCE
# 574        753                     DISCHARGE FIREARMS/SHOTS FIRED
# 576        940                                          EXTORTION
# 613        250   SHOTS FIRED AT MOVING VEHICLE, TRAIN OR AIRCRAFT
# 620        231       ASSAULT WITH DEADLY WEAPON ON POLICE OFFICER
# 627        664                                 BUNCO, PETTY THEFT
# 766        437                                   RESISTING ARREST
# 786        902           VIOLATION OF TEMPORARY RESTRAINING ORDER
# 788        813                     CHILD ANNOYING (17YRS & UNDER)
# 811        251                  SHOTS FIRED AT INHABITED DWELLING
# 841        410                   BURGLARY FROM VEHICLE, ATTEMPTED
# 850        647                  THROWING OBJECT AT MOVING VEHICLE
# 907        810  SEX,UNLAWFUL(INC MUTUAL CONSENT, PENETRATION W...
# 993        820                                    ORAL COPULATION
# 1113       815                SEXUAL PENETRATION W/FOREIGN OBJECT
# 1196       762                                       LEWD CONDUCT
# 1202       352                                         PICKPOCKET
# 1393       922                                     CHILD STEALING
# 1441       351                                    PURSE SNATCHING
# 1513       421                 THEFT FROM MOTOR VEHICLE - ATTEMPT
# 1592       822            HUMAN TRAFFICKING - COMMERCIAL SEX ACTS
# 1598       850                                  INDECENT EXPOSURE
# 1616       444                   DISHONEST EMPLOYEE - PETTY THEFT
# 1648       670           EMBEZZLEMENT, PETTY THEFT ($950 & UNDER)
# 1797       910                                         KIDNAPPING
# 1857       886                               DISTURBING THE PEACE
# 1912       661                       UNAUTHORIZED COMPUTER ACCESS
# 2012       110                                  CRIMINAL HOMICIDE
# 2025       441                              THEFT PLAIN - ATTEMPT
# 2107       931  REPLICA FIREARMS(SALE,DISPLAY,MANUFACTURE OR D...
# 2298       435                                           LYNCHING
# 2338       438                                   RECKLESS DRIVING
# 2418       928                    THREATENING PHONE CALLS/LETTERS
# 2547       443                              SHOPLIFTING - ATTEMPT
# 2740       755                                         BOMB SCARE
# 2816       235        CHILD ABUSE (PHYSICAL) - AGGRAVATED ASSAULT
# 2897       763                                           STALKING
# 3181       433               DRIVING WITHOUT OWNER CONSENT (DWOC)
# 3419       622                           BATTERY ON A FIREFIGHTER
# 3543       932                                        PEEPING TOM
# 3992       439                                FALSE POLICE REPORT
# 4120       487                                      BOAT - STOLEN
# 4231       951  DEFRAUDING INNKEEPER/THEFT OF SERVICES, $950 &...
# 4239       949                                    ILLEGAL DUMPING
# 5192       865                                  DRUGS, TO A MINOR
# 6131       474         THEFT, COIN MACHINE - PETTY ($950 & UNDER)
# 7300       654              CREDIT CARDS, FRAUD USE ($950 & UNDER
# 7395       113                            MANSLAUGHTER, NEGLIGENT
# 7853       450                        THEFT FROM PERSON - ATTEMPT
# 7936       920                         KIDNAPPING - GRAND ATTEMPT
# 8239       475                      THEFT, COIN MACHINE - ATTEMPT
# 8629       446                          PETTY THEFT - AUTO REPAIR
# 8834       652                  DOCUMENT WORTHLESS ($200 & UNDER)
# 8983       434                                 FALSE IMPRISONMENT
# 9997       653           CREDIT CARDS, FRAUD USE ($950.01 & OVER)
# 10066      950  DEFRAUDING INNKEEPER/THEFT OF SERVICES, OVER $...
# 10084      814                                  CHILD PORNOGRAPHY
# 11002      806                                          PANDERING
# 11032      921          HUMAN TRAFFICKING - INVOLUNTARY SERVITUDE
# 11570      943                                 CRUELTY TO ANIMALS
# 11902      660                                        COUNTERFEIT
# 13360      345                   DISHONEST EMPLOYEE - GRAND THEFT
# 15514      933                                            PROWLER
# 18653      651                DOCUMENT WORTHLESS ($200.01 & OVER)
# 19578      756                         WEAPONS POSSESSION/BOMBING
# 24945      349                          GRAND THEFT / AUTO REPAIR
# 25032      944                                         CONSPIRACY
# 38636      353                                         DRUNK ROLL
# 39277      436                               LYNCHING - ATTEMPTED
# 46381      473       THEFT, COIN MACHINE - GRAND ($950.01 & OVER)
# 47176      880                                     DISRUPT SCHOOL
# 53546      471                    TILL TAP - PETTY ($950 & UNDER)
# 54458      452                                PICKPOCKET, ATTEMPT
# 85058      347                      GRAND THEFT / INSURANCE FRAUD
# 86529      470            TILL TAP - GRAND THEFT ($950.01 & OVER)
# 97717      451                          PURSE SNATCHING - ATTEMPT
# 110416     485                            BIKE - ATTEMPTED STOLEN
# 121853     942                                            BRIBERY
# 146533     870                                  CHILD ABANDONMENT
# 200422     924                        TELEPHONE PROPERTY - DAMAGE
# 209644     840  BEASTIALITY, CRIME AGAINST NATURE SEXUAL ASSLT...
# 222059     948                                             BIGAMY
# 230217     884                                FAILURE TO DISPERSE
# 241944     904  FIREARMS EMERGENCY PROTECTIVE ORDER (FIREARMS ...
# 329282     830       INCEST (SEXUAL ACTS BETWEEN BLOOD RELATIVES)
# 472993     432                     BLOCKING DOOR INDUCTION CENTER
# 532899     882                                    INCITING A RIOT
# 552739     445                 DISHONEST EMPLOYEE ATTEMPTED THEFT
# 947756     926                                     TRAIN WRECKING
# 964262     453                               DRUNK ROLL - ATTEMPT

# %% [markdown]
# ### Exporting the data
#
# Export the DataFrame to a CSV file for loading into Tableau

# %%
df.to_csv('cleaned_LA_crime_dataset.csv', index=False)
